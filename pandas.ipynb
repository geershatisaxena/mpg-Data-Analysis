# %% [markdown]
# ## **Importing the Libraries**

# %%
import seaborn as sns
import pandas as pd

# %% [markdown]
# ## **Importing the Dataset**

# %%
df = sns.load_dataset("mpg")

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %% [markdown]
# #### **🔹 Basic Exploration**

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
df.tail()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin             name
# 393          82     usa  ford mustang gl
# 394          82  europe        vw pickup
# 395          82     usa    dodge rampage
# 396          82     usa      ford ranger
# 397          82     usa       chevy s-10

# %%
df.shape
# Out:
# (398, 9)

# %%
df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=398, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
df.describe(include="all")
# Out:
#                mpg   cylinders  displacement  horsepower       weight  \
# count   398.000000  398.000000    398.000000  392.000000   398.000000
# unique         NaN         NaN           NaN         NaN          NaN
# top            NaN         NaN           NaN         NaN          NaN
# freq           NaN         NaN           NaN         NaN          NaN
# mean     23.514573    5.454774    193.425879  104.469388  2970.424623
# std       7.815984    1.701004    104.269838   38.491160   846.841774
# min       9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%      17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%      23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%      29.000000    8.000000    262.000000  126.000000  3608.000000
# max      46.600000    8.000000    455.000000  230.000000  5140.000000
#
#         acceleration  model_year origin        name
# count     398.000000  398.000000    398         398
# ...

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin           object
# name             object
# dtype: object

# %%
df.sample(5)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 21   24.0          4         107.0        90.0    2430          14.5
# 197  29.0          4          90.0        70.0    1937          14.2
# 333  32.7          6         168.0       132.0    2910          11.4
# 346  32.3          4          97.0        67.0    2065          17.8
# 395  32.0          4         135.0        84.0    2295          11.6
#
#      model_year  origin           name
# 21           70  europe    audi 100 ls
# 197          76  europe      vw rabbit
# 333          80   japan  datsun 280-zx
# 346          81   japan         subaru
# 395          82     usa  dodge rampage

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# mpg             129
# cylinders         5
# displacement     82
# horsepower       93
# weight          351
# acceleration     95
# model_year       13
# origin            3
# name            305
# dtype: int64

# %%
df.memory_usage()
# Out:
# Index            132
# mpg             3184
# cylinders       3184
# displacement    3184
# horsepower      3184
# weight          3184
# acceleration    3184
# model_year      3184
# origin          3184
# name            3184
# dtype: int64

# %%
df.memory_usage(deep=True)
# Out:
# Index             132
# mpg              3184
# cylinders        3184
# displacement     3184
# horsepower       3184
# weight           3184
# acceleration     3184
# model_year       3184
# origin          21064
# name            25908
# dtype: int64

# %% [markdown]
# #### **🔹 Column Selection**

# %%
df["mpg"]
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
df[["mpg", "horsepower"]]
# Out:
#       mpg  horsepower
# 0    18.0       130.0
# 1    15.0       165.0
# 2    18.0       150.0
# 3    16.0       150.0
# 4    17.0       140.0
# ..    ...         ...
# 393  27.0        86.0
# 394  44.0        52.0
# 395  32.0        84.0
# 396  28.0        79.0
# 397  31.0        82.0
#
# [398 rows x 2 columns]

# %%
df.loc[:, "mpg"]
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
df.iloc[:, 0]
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
df.select_dtypes(include="number")
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year
# 0            70
# 1            70
# 2            70
# 3            70
# 4            70
# ..          ...
# ...

# %%
df.select_dtypes(include="object")
# Out:
#      origin                       name
# 0       usa  chevrolet chevelle malibu
# 1       usa          buick skylark 320
# 2       usa         plymouth satellite
# 3       usa              amc rebel sst
# 4       usa                ford torino
# ..      ...                        ...
# 393     usa            ford mustang gl
# 394  europe                  vw pickup
# 395     usa              dodge rampage
# 396     usa                ford ranger
# 397     usa                 chevy s-10
#
# [398 rows x 2 columns]

# %%
df.filter(like="acc")
# Out:
#      acceleration
# 0            12.0
# 1            11.5
# 2            11.0
# 3            12.0
# 4            10.5
# ..            ...
# 393          15.6
# 394          24.6
# 395          11.6
# 396          18.6
# 397          19.4
#
# [398 rows x 1 columns]

# %%
df.filter(regex="^c")
# Out:
#      cylinders
# 0            8
# 1            8
# 2            8
# 3            8
# 4            8
# ..         ...
# 393          4
# 394          4
# 395          4
# 396          4
# 397          4
#
# [398 rows x 1 columns]

# %%
 df.loc[0]
# Out:
# mpg                                  18.0
# cylinders                               8
# displacement                        307.0
# horsepower                          130.0
# weight                               3504
# acceleration                         12.0
# model_year                             70
# origin                                usa
# name            chevrolet chevelle malibu
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# mpg                                  18.0
# cylinders                               8
# displacement                        307.0
# horsepower                          130.0
# weight                               3504
# acceleration                         12.0
# model_year                             70
# origin                                usa
# name            chevrolet chevelle malibu
# Name: 0, dtype: object

# %% [markdown]
# #### **🔹 Filtering**

# %%
df[df["mpg"] > 30]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 53   31.0          4          71.0        65.0    1773          19.0
# 54   35.0          4          72.0        69.0    1613          18.0
# 129  31.0          4          79.0        67.0    1950          19.0
# 131  32.0          4          71.0        65.0    1836          21.0
# 144  31.0          4          76.0        52.0    1649          16.5
# ..    ...        ...           ...         ...     ...           ...
# 390  32.0          4         144.0        96.0    2665          13.9
# 391  36.0          4         135.0        84.0    2370          13.0
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                 name
# 53           71   japan  toyota corolla 1200
# 54           71   japan          datsun 1200
# ...

# %%
df[df["horsepower"] < 100]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 14   24.0          4         113.0        95.0    2372          15.0
# 15   22.0          6         198.0        95.0    2833          15.5
# 16   18.0          6         199.0        97.0    2774          15.5
# 17   21.0          6         200.0        85.0    2587          16.0
# 18   27.0          4          97.0        88.0    2130          14.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                   name
# 14           70   japan  toyota corona mark ii
# ...

# %%
df[df["origin"] == "usa"]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 392  27.0          4         151.0        90.0    2950          17.3
# 393  27.0          4         140.0        86.0    2790          15.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year origin                       name
# 0            70    usa  chevrolet chevelle malibu
# ...

# %%
df[(df["mpg"] > 25) & (df["cylinders"] == 4)]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 18   27.0          4          97.0        88.0    2130          14.5
# 19   26.0          4          97.0        46.0    1835          20.5
# 23   26.0          4         121.0       113.0    2234          12.5
# 29   27.0          4          97.0        88.0    2130          14.5
# 30   28.0          4         140.0        90.0    2264          15.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                          name
# 18           70   japan                  datsun pl510
# ...

# %%
df[(df["weight"] > 3000) | (df["horsepower"] > 150)]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 364  26.6          8         350.0       105.0    3725          19.0
# 365  20.2          6         200.0        88.0    3060          17.1
# 366  17.6          6         225.0        85.0    3465          16.6
# 374  23.0          4         151.0         NaN    3035          20.5
# 387  38.0          6         262.0        85.0    3015          17.0
#
#      model_year origin                               name
# 0            70    usa          chevrolet chevelle malibu
# ...

# %%
df[df["model_year"] >= 80]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 309  41.5          4          98.0        76.0    2144          14.7
# 310  38.1          4          89.0        60.0    1968          18.8
# 311  32.1          4          98.0        70.0    2120          15.5
# 312  37.2          4          86.0        65.0    2019          16.4
# 313  28.0          4         151.0        90.0    2678          16.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                   name
# 309          80  europe              vw rabbit
# ...

# %%
df[df["name"].str.contains("ford")]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 4    17.0          8         302.0       140.0    3449          10.5
# 5    15.0          8         429.0       198.0    4341          10.0
# 17   21.0          6         200.0        85.0    2587          16.0
# 25   10.0          8         360.0       215.0    4615          14.0
# 32   25.0          4          98.0         NaN    2046          19.0
# 36   19.0          6         250.0        88.0    3302          15.5
# 40   14.0          8         351.0       153.0    4154          13.5
# 43   13.0          8         400.0       170.0    4746          12.0
# 48   18.0          6         250.0        88.0    3139          14.5
# 61   21.0          4         122.0        86.0    2226          16.5
# 65   14.0          8         351.0       153.0    4129          13.0
# 74   13.0          8         302.0       140.0    4294          16.0
# 80   22.0          4         122.0        86.0    2395          16.0
# ...

# %%
df[df["acceleration"].between(10,15)]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 388  26.0          4         156.0        92.0    2585          14.5
# 389  22.0          6         232.0       112.0    2835          14.7
# 390  32.0          4         144.0        96.0    2665          13.9
# 391  36.0          4         135.0        84.0    2370          13.0
# 395  32.0          4         135.0        84.0    2295          11.6
#
#      model_year origin                        name
# 0            70    usa   chevrolet chevelle malibu
# ...

# %%
df[df["origin"].isin(["japan","europe"])]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 14   24.0          4         113.0        95.0    2372          15.0
# 18   27.0          4          97.0        88.0    2130          14.5
# 19   26.0          4          97.0        46.0    1835          20.5
# 20   25.0          4         110.0        87.0    2672          17.5
# 21   24.0          4         107.0        90.0    2430          14.5
# ..    ...        ...           ...         ...     ...           ...
# 383  38.0          4          91.0        67.0    1965          15.0
# 384  32.0          4          91.0        67.0    1965          15.7
# 385  38.0          4          91.0        67.0    1995          16.2
# 390  32.0          4         144.0        96.0    2665          13.9
# 394  44.0          4          97.0        52.0    2130          24.6
#
#      model_year  origin                          name
# 14           70   japan         toyota corona mark ii
# ...

# %%
df[~df["origin"].isin(["usa"])]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 14   24.0          4         113.0        95.0    2372          15.0
# 18   27.0          4          97.0        88.0    2130          14.5
# 19   26.0          4          97.0        46.0    1835          20.5
# 20   25.0          4         110.0        87.0    2672          17.5
# 21   24.0          4         107.0        90.0    2430          14.5
# ..    ...        ...           ...         ...     ...           ...
# 383  38.0          4          91.0        67.0    1965          15.0
# 384  32.0          4          91.0        67.0    1965          15.7
# 385  38.0          4          91.0        67.0    1995          16.2
# 390  32.0          4         144.0        96.0    2665          13.9
# 394  44.0          4          97.0        52.0    2130          24.6
#
#      model_year  origin                          name
# 14           70   japan         toyota corona mark ii
# ...

# %%
df[df["mpg"].notnull()]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
df[df["horsepower"].isnull()]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 32   25.0          4          98.0         NaN    2046          19.0
# 126  21.0          6         200.0         NaN    2875          17.0
# 330  40.9          4          85.0         NaN    1835          17.3
# 336  23.6          4         140.0         NaN    2905          14.3
# 354  34.5          4         100.0         NaN    2320          15.8
# 374  23.0          4         151.0         NaN    3035          20.5
#
#      model_year  origin                  name
# 32           71     usa            ford pinto
# 126          74     usa         ford maverick
# 330          80  europe  renault lecar deluxe
# 336          80     usa    ford mustang cobra
# 354          81  europe           renault 18i
# 374          82     usa        amc concord dl

# %%
df.query("mpg > 20")
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 14   24.0          4         113.0        95.0    2372          15.0
# 15   22.0          6         198.0        95.0    2833          15.5
# 17   21.0          6         200.0        85.0    2587          16.0
# 18   27.0          4          97.0        88.0    2130          14.5
# 19   26.0          4          97.0        46.0    1835          20.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                          name
# 14           70   japan         toyota corona mark ii
# ...

# %%
df.query("cylinders == 6 and origin == 'usa'")
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 15   22.0          6         198.0        95.0    2833          15.5
# 16   18.0          6         199.0        97.0    2774          15.5
# 17   21.0          6         200.0        85.0    2587          16.0
# 24   21.0          6         199.0        90.0    2648          15.0
# 33   19.0          6         232.0       100.0    2634          13.0
# ..    ...        ...           ...         ...     ...           ...
# 365  20.2          6         200.0        88.0    3060          17.1
# 366  17.6          6         225.0        85.0    3465          16.6
# 386  25.0          6         181.0       110.0    2945          16.4
# 387  38.0          6         262.0        85.0    3015          17.0
# 389  22.0          6         232.0       112.0    2835          14.7
#
#      model_year origin                               name
# 15           70    usa                    plymouth duster
# ...

# %%
df.query("weight > 2500")
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 390  32.0          4         144.0        96.0    2665          13.9
# 392  27.0          4         151.0        90.0    2950          17.3
# 393  27.0          4         140.0        86.0    2790          15.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year origin                       name
# 0            70    usa  chevrolet chevelle malibu
# ...

# %% [markdown]
# #### **🔹 Sorting**

# %%
df.sort_values("mpg")
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 28    9.0          8         304.0       193.0    4732          18.5
# 25   10.0          8         360.0       215.0    4615          14.0
# 26   10.0          8         307.0       200.0    4376          15.0
# 103  11.0          8         400.0       150.0    4997          14.0
# 67   11.0          8         429.0       208.0    4633          11.0
# ..    ...        ...           ...         ...     ...           ...
# 326  43.4          4          90.0        48.0    2335          23.7
# 394  44.0          4          97.0        52.0    2130          24.6
# 325  44.3          4          90.0        48.0    2085          21.7
# 329  44.6          4          91.0        67.0    1850          13.8
# 322  46.6          4          86.0        65.0    2110          17.9
#
#      model_year  origin                  name
# 28           70     usa              hi 1200d
# ...

# %%
df.sort_values("mpg", ascending=False)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 322  46.6          4          86.0        65.0    2110          17.9
# 329  44.6          4          91.0        67.0    1850          13.8
# 325  44.3          4          90.0        48.0    2085          21.7
# 394  44.0          4          97.0        52.0    2130          24.6
# 326  43.4          4          90.0        48.0    2335          23.7
# ..    ...        ...           ...         ...     ...           ...
# 27   11.0          8         318.0       210.0    4382          13.5
# 67   11.0          8         429.0       208.0    4633          11.0
# 25   10.0          8         360.0       215.0    4615          14.0
# 26   10.0          8         307.0       200.0    4376          15.0
# 28    9.0          8         304.0       193.0    4732          18.5
#
#      model_year  origin                  name
# 322          80   japan             mazda glc
# ...

# %%
df.sort_values(["origin","mpg"])
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 277  16.2          6         163.0       133.0    3410          15.8
# 211  16.5          6         168.0       120.0    3820          16.7
# 275  17.0          6         163.0       125.0    3140          13.6
# 76   18.0          4         121.0       112.0    2933          14.5
# 120  19.0          4         121.0       112.0    2868          15.5
# ..    ...        ...           ...         ...     ...           ...
# 391  36.0          4         135.0        84.0    2370          13.0
# 245  36.1          4          98.0        66.0    1800          14.4
# 378  38.0          4         105.0        63.0    2125          14.7
# 387  38.0          6         262.0        85.0    3015          17.0
# 344  39.0          4          86.0        64.0    1875          16.4
#
#      model_year  origin                               name
# 277          78  europe                      peugeot 604sl
# ...

# %%
df.sort_values(["origin","mpg"], ascending=[True,False])
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 325  44.3          4          90.0        48.0    2085          21.7
# 394  44.0          4          97.0        52.0    2130          24.6
# 326  43.4          4          90.0        48.0    2335          23.7
# 244  43.1          4          90.0        48.0    1985          21.5
# 309  41.5          4          98.0        76.0    2144          14.7
# ..    ...        ...           ...         ...     ...           ...
# 103  11.0          8         400.0       150.0    4997          14.0
# 124  11.0          8         350.0       180.0    3664          11.0
# 25   10.0          8         360.0       215.0    4615          14.0
# 26   10.0          8         307.0       200.0    4376          15.0
# 28    9.0          8         304.0       193.0    4732          18.5
#
#      model_year  origin                             name
# 325          80  europe             vw rabbit c (diesel)
# ...

# %%
df.sort_index()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %% [markdown]
# #### **🔹 Aggregations**

# %%
df["mpg"].mean()
# Out:
# np.float64(23.514572864321607)

# %%
df["mpg"].median()
# Out:
# np.float64(23.0)

# %%
df["mpg"].mode()
# Out:
# 0    13.0
# Name: mpg, dtype: float64

# %%
df["mpg"].min()
# Out:
# np.float64(9.0)

# %%
df["mpg"].max()
# Out:
# np.float64(46.6)

# %%
df["mpg"].sum()
# Out:
# np.float64(9358.8)

# %%
df["mpg"].std()
# Out:
# np.float64(7.815984312565782)

# %%
df["mpg"].var()
# Out:
# np.float64(61.089610774274405)

# %%
df["mpg"].count()
# Out:
# np.int64(398)

# %%
df["cylinders"].value_counts()
# Out:
# cylinders
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: count, dtype: int64

# %%
df["origin"].value_counts(normalize=True)
# Out:
# origin
# usa       0.625628
# japan     0.198492
# europe    0.175879
# Name: proportion, dtype: float64

# %%
df.groupby("origin")["mpg"].mean()
# Out:
# origin
# europe    27.891429
# japan     30.450633
# usa       20.083534
# Name: mpg, dtype: float64

# %%
 df.groupby("cylinders")["horsepower"].mean()
# Out:
# cylinders
# 3     99.250000
# 4     78.281407
# 5     82.333333
# 6    101.506024
# 8    158.300971
# Name: horsepower, dtype: float64

# %%
df.groupby(["origin","cylinders"])["mpg"].mean()
# Out:
# origin  cylinders
# europe  4            28.411111
#         5            27.366667
#         6            20.100000
# japan   3            20.550000
#         4            31.595652
#         6            23.883333
# usa     4            27.840278
#         6            19.663514
#         8            14.963107
# Name: mpg, dtype: float64

# %%
df.agg({"mpg":["mean","max"],"horsepower":["min","max"]})
# Out:
#             mpg  horsepower
# mean  23.514573         NaN
# max   46.600000       230.0
# min         NaN        46.0

# %% [markdown]
# #### **🔹 GroupBy Advanced**

# %%
df.groupby("origin").size()
# Out:
# origin
# europe     70
# japan      79
# usa       249
# dtype: int64

# %%
df.groupby("origin")["weight"].sum()
# Out:
# origin
# europe    169631
# japan     175477
# usa       837121
# Name: weight, dtype: int64

# %%
df.groupby("origin")["weight"].agg(["mean","max"])
# Out:
#                mean   max
# origin
# europe  2423.300000  3820
# japan   2221.227848  2930
# usa     3361.931727  5140

# %%
df.groupby("cylinders").describe()
# Out:
#              mpg                                                        \
#            count       mean       std   min    25%    50%    75%   max
# cylinders
# 3            4.0  20.550000  2.564501  18.0  18.75  20.25  22.05  23.7
# 4          204.0  29.286765  5.710156  18.0  25.00  28.25  33.00  46.6
# 5            3.0  27.366667  8.228204  20.3  22.85  25.40  30.90  36.4
# 6           84.0  19.985714  3.807322  15.0  18.00  19.00  21.00  38.0
# 8          103.0  14.963107  2.836284   9.0  13.00  14.00  16.00  26.6
#
#           displacement              ... acceleration       model_year  \
#                  count        mean  ...          75%   max      count
# cylinders                           ...
# 3                  4.0   72.500000  ...         13.5  13.5        4.0
# 4                204.0  109.796569  ...         18.0  24.8      204.0
# 5                  3.0  145.000000  ...         20.0  20.1        3.0
# ...

# %%
df.groupby("model_year")["mpg"].mean()
# Out:
# model_year
# 70    17.689655
# 71    21.250000
# 72    18.714286
# 73    17.100000
# 74    22.703704
# 75    20.266667
# 76    21.573529
# 77    23.375000
# 78    24.061111
# 79    25.093103
# 80    33.696552
# 81    30.334483
# 82    31.709677
# Name: mpg, dtype: float64

# %%
df.groupby("origin")["mpg"].transform("mean")
# Out:
# 0      20.083534
# 1      20.083534
# 2      20.083534
# 3      20.083534
# 4      20.083534
#          ...
# 393    20.083534
# 394    27.891429
# 395    20.083534
# 396    20.083534
# 397    20.083534
# Name: mpg, Length: 398, dtype: float64

# %%
df.groupby("origin").filter(lambda x: x["mpg"].mean() > 25)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 14   24.0          4         113.0        95.0    2372          15.0
# 18   27.0          4          97.0        88.0    2130          14.5
# 19   26.0          4          97.0        46.0    1835          20.5
# 20   25.0          4         110.0        87.0    2672          17.5
# 21   24.0          4         107.0        90.0    2430          14.5
# ..    ...        ...           ...         ...     ...           ...
# 383  38.0          4          91.0        67.0    1965          15.0
# 384  32.0          4          91.0        67.0    1965          15.7
# 385  38.0          4          91.0        67.0    1995          16.2
# 390  32.0          4         144.0        96.0    2665          13.9
# 394  44.0          4          97.0        52.0    2130          24.6
#
#      model_year  origin                          name
# 14           70   japan         toyota corona mark ii
# ...

# %%
df.groupby("origin").nth(0)
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0   18.0          8         307.0       130.0    3504          12.0
# 14  24.0          4         113.0        95.0    2372          15.0
# 19  26.0          4          97.0        46.0    1835          20.5
#
#     model_year  origin                          name
# 0           70     usa     chevrolet chevelle malibu
# 14          70   japan         toyota corona mark ii
# 19          70  europe  volkswagen 1131 deluxe sedan

# %%
df.groupby("origin").first()
# Out:
#          mpg  cylinders  displacement  horsepower  weight  acceleration  \
# origin
# europe  26.0          4          97.0        46.0    1835          20.5
# japan   24.0          4         113.0        95.0    2372          15.0
# usa     18.0          8         307.0       130.0    3504          12.0
#
#         model_year                          name
# origin
# europe          70  volkswagen 1131 deluxe sedan
# japan           70         toyota corona mark ii
# usa             70     chevrolet chevelle malibu

# %%
df.groupby("origin").last()
# Out:
#          mpg  cylinders  displacement  horsepower  weight  acceleration  \
# origin
# europe  44.0          4          97.0        52.0    2130          24.6
# japan   32.0          4         144.0        96.0    2665          13.9
# usa     31.0          4         119.0        82.0    2720          19.4
#
#         model_year              name
# origin
# europe          82         vw pickup
# japan           82  toyota celica gt
# usa             82        chevy s-10

# %% [markdown]
# #### **🔹 Handling Missing Data**

# %%
df.dropna()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
df.dropna(subset=["horsepower"])
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
df.fillna(0)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
df["horsepower"].fillna(df["horsepower"].mean())
# Out:
# 0      130.0
# 1      165.0
# 2      150.0
# 3      150.0
# 4      140.0
#        ...
# 393     86.0
# 394     52.0
# 395     84.0
# 396     79.0
# 397     82.0
# Name: horsepower, Length: 398, dtype: float64

# %%
df["horsepower"].interpolate()
# Out:
# 0      130.0
# 1      165.0
# 2      150.0
# 3      150.0
# 4      140.0
#        ...
# 393     86.0
# 394     52.0
# 395     84.0
# 396     79.0
# 397     82.0
# Name: horsepower, Length: 398, dtype: float64

# %% [markdown]
# #### **🔹 Column Operations**

# %%
df["power_to_weight"] = df["horsepower"] / df["weight"]

# %%
df["mpg_kmpl"] = df["mpg"] * 0.425144

# %%
 df.rename(columns={"mpg":"miles_per_gallon"})
# Out:
#      miles_per_gallon  cylinders  displacement  horsepower  weight  \
# 0                18.0          8         307.0       130.0    3504
# 1                15.0          8         350.0       165.0    3693
# 2                18.0          8         318.0       150.0    3436
# 3                16.0          8         304.0       150.0    3433
# 4                17.0          8         302.0       140.0    3449
# ..                ...        ...           ...         ...     ...
# 393              27.0          4         140.0        86.0    2790
# 394              44.0          4          97.0        52.0    2130
# 395              32.0          4         135.0        84.0    2295
# 396              28.0          4         120.0        79.0    2625
# 397              31.0          4         119.0        82.0    2720
#
#      acceleration  model_year  origin                       name  \
# 0            12.0          70     usa  chevrolet chevelle malibu
# ...

# %%
df.drop(columns=["name"])
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin  power_to_weight   mpg_kmpl
# 0            70     usa         0.037100   7.652592
# ...

# %%
df.assign(double_weight=df["weight"]*2)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name  power_to_weight  \
# 0            70     usa  chevrolet chevelle malibu         0.037100
# ...

# %%
df["origin_code"] = df["origin"].map({"usa":1,"europe":2,"japan":3})

# %%
df["car_age"] = 1982 - df["model_year"]

# %%
df["high_mpg"] = df["mpg"] > df["mpg"].mean()

# %%
df["mpg"].apply(lambda x: x*2)
# Out:
# 0      36.0
# 1      30.0
# 2      36.0
# 3      32.0
# 4      34.0
#        ...
# 393    54.0
# 394    88.0
# 395    64.0
# 396    56.0
# 397    62.0
# Name: mpg, Length: 398, dtype: float64

# %%
df["cylinders"].astype("category")
# Out:
# 0      8
# 1      8
# 2      8
# 3      8
# 4      8
#       ..
# 393    4
# 394    4
# 395    4
# 396    4
# 397    4
# Name: cylinders, Length: 398, dtype: category
# Categories (5, int64): [3, 4, 5, 6, 8]

# %% [markdown]
# #### **🔹 Indexing & Resetting**

# %%
df.set_index("name")
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0        86.0    2790
# vw pickup                  44.0          4          97.0        52.0    2130
# dodge rampage              32.0          4         135.0        84.0    2295
# ford ranger                28.0          4         120.0        79.0    2625
# chevy s-10                 31.0          4         119.0        82.0    2720
#
# ...

# %%
df.reset_index()
# Out:
#      index   mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0        0  18.0          8         307.0       130.0    3504          12.0
# 1        1  15.0          8         350.0       165.0    3693          11.5
# 2        2  18.0          8         318.0       150.0    3436          11.0
# 3        3  16.0          8         304.0       150.0    3433          12.0
# 4        4  17.0          8         302.0       140.0    3449          10.5
# ..     ...   ...        ...           ...         ...     ...           ...
# 393    393  27.0          4         140.0        86.0    2790          15.6
# 394    394  44.0          4          97.0        52.0    2130          24.6
# 395    395  32.0          4         135.0        84.0    2295          11.6
# 396    396  28.0          4         120.0        79.0    2625          18.6
# 397    397  31.0          4         119.0        82.0    2720          19.4
#
# ...

# %%
df.set_index(["origin","name"])
# Out:
#                                    mpg  cylinders  displacement  horsepower  \
# origin name
# usa    chevrolet chevelle malibu  18.0          8         307.0       130.0
#        buick skylark 320          15.0          8         350.0       165.0
#        plymouth satellite         18.0          8         318.0       150.0
#        amc rebel sst              16.0          8         304.0       150.0
#        ford torino                17.0          8         302.0       140.0
# ...                                ...        ...           ...         ...
#        ford mustang gl            27.0          4         140.0        86.0
# europe vw pickup                  44.0          4          97.0        52.0
# usa    dodge rampage              32.0          4         135.0        84.0
#        ford ranger                28.0          4         120.0        79.0
#        chevy s-10                 31.0          4         119.0        82.0
#
# ...

# %%
df.sort_index()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name  power_to_weight  \
# 0            70     usa  chevrolet chevelle malibu         0.037100
# ...

# %%
df.loc[df.index[:5]]
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name  power_to_weight  mpg_kmpl  \
# 0          70    usa  chevrolet chevelle malibu         0.037100  7.652592
# 1          70    usa          buick skylark 320         0.044679  6.377160
# 2          70    usa         plymouth satellite         0.043655  7.652592
# 3          70    usa              amc rebel sst         0.043694  6.802304
# 4          70    usa                ford torino         0.040591  7.227448
#
#    origin_code  car_age  high_mpg
# 0            1     1912     False
# 1            1     1912     False
# ...
